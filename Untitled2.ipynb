# %% [markdown]
# This code is to implement for generating markov chain whose state is in the range 0 to 2^16. If the last bit is 1, we change the last bit to 0 and put in the Markov chain again. In the next code we try to find the entropy. The next code is- https://colab.research.google.com/drive/1cLSVyCgBaz6_4981UmHyJ9KpqALNXcC6

# %%
import numpy as np
import random
from matplotlib import pyplot as plt

# %%
for i in range(20):
 a=(random.randint(0, 65536))
 print(a)
 b=a&1
 if b==1:
   a=a&(65534)
 print(a)
# Out:
# 60670
# 60670
# 29750
# 29750
# 65483
# 65482
# 40591
# 40590
# 29877
# 29876
# 8860
# 8860
# 35332
# 35332
# 15542
# 15542
# 14360
# 14360
# 48797
# 48796
# 19719
# 19718
# 57711
# 57710
# 11218
# 11218
# 65297
# 65296
# 3847
# 3846
# 17433
# 17432
# 23519
# 23518
# 52636
# 52636
# 9316
# 9316
# 23601
# 23600

# %%
lst=[]
last_bit=[]
new_updated_value=[]
x = np.linspace(1, 20, num=20)
i=0
for i in range(20):
 a=(random.randint(0, 65536))
 lst.append(a)
 b=a&1
 last_bit.append(b)
 if b==1:
   a=a&(65534)
   new_updated_value.append(a)
#plt.plot(x,lst)
plt.plot(x,last_bit)
